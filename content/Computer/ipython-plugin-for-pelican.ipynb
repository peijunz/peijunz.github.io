# %% [markdown]
# # ipynb2pelican Plugin released!
# + date: 2017-03-27
# + summary: Yet another Pelican Plugin for blogging with Jupyter Notebooks using MetaCell to store metadata
# + slug: ipynb-plugin
# + tags: [pelican, python, jupyter]

# %% [markdown]
# Thanks to super cow power of python, we can finally publish ipynb easily!
#
# Please visit <https://github.com/peijunz/ipynb2pelican> for more information about the plugin.
