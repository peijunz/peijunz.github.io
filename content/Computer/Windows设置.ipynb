# %% [markdown]
# # Windows设置
# + date: 2017-10-06

# %% [markdown]
# + 压缩[7-zip](http://www.7-zip.org/download.html)
# + pdf阅读器
#     + [Adobe Reader](https://get.adobe.com/cn/reader/otherversions/)
#     + [Master PDF Editor](https://code-industry.net/get-masterpdfeditor/)
# + [WPS](http://www.wps.cn/product)
# + 图像处理
#     + 点阵图[Gimp](https://www.gimp.org/downloads/)
#     + 矢量图[Inkscape](https://inkscape.org/zh/download/)
# + 代码开发
#     + [Code::Blocks](http://www.codeblocks.org/downloads/26)
#     + [QtCreator](https://download.qt.io/official_releases/qtcreator/)
#     + [VS Code](https://code.visualstudio.com/download)
#     + [Mingw-w64](https://mingw-w64.org/doku.php/download)
# + 浏览器
#     + [Firefox中文版](https://www.mozilla.org/en-US/firefox/all/?q=Chinese)
#     + [Chrome](https://www.google.cn/chrome/browser/desktop/index.html)
# + 编辑器
#     + [SublimeText](https://www.sublimetext.com/3)
#     + [Notepad++](https://notepad-plus-plus.org/download/v7.5.1.html)
# + 网盘dropbox, megasync
# + 词典[Goldendict](http://goldendict.org/download.php), 欧路词典
