# %% [markdown]
# # 带单侧吸收壁的随机游走
# + date: 2017-04-20
# + slug: random-walk-with-single-absorption
# + status: draft
# + tags: math

# %% [markdown]
# 如何搞

# %% [markdown]
# $$[p_i\sigma_i, \sigma_j]e_j\hbar/2=p_ie_ji\hbar\epsilon_{ijk}s_k=i\hbar \sigma\times p$$,
# $$[p_\sigma, r]\times p=-i\hbar \sigma\times p$$
